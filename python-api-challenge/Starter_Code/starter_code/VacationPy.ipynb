# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  cabo san lucas  22.8909 -109.9124     32.01        54          80
# 1        1     lionel town  17.8101  -77.2406     32.94        68          99
# 2        2   blackmans bay -43.0167  147.3167      9.29        70          58
# 3        3         isabela   6.7085  121.9711     26.11        86          59
# 4        4         matoury   4.8483  -52.3317     29.98        70          20
#
#    Wind Speed Country        Date
# 0        0.45      MX  1699991945
# 1        6.62      JM  1699992026
# 2        1.37      AU  1699992026
# 3        0.61      PH  1699992026
# 4        4.63      GF  1699992027

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = city_data_df.hvplot.points('Lng','Lat',
                                      geo=True,
                                      size = "Humidity",
                                     scale= 1,
                                     color = "City",
                                     alpha= 0.5,
                                     tiles = True)
    
# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
narrowed_city_df = city_data_df.loc[(city_data_df["Max Temp"]<27) \
                                    & (city_data_df["Max Temp"]>21)\
                                   & (city_data_df["Wind Speed"]<4.5)\
                                    & (city_data_df["Cloudiness"]== 0)]

# Drop any rows with null values
narrowed_city_df= narrowed_city_df.dropna()

# Display sample data
narrowed_city_df
# Out:
#      City_ID                City      Lat       Lng  Max Temp  Humidity  \
# 32        32        aransas pass  27.9095  -97.1500     23.87        76
# 33        33    minas de marcona -15.2119  -75.1103     24.73        46
# 67        67           las vegas  36.1750 -115.1372     22.91        25
# 82        82              newman  37.3138 -121.0208     23.46        27
# 129      129          errachidia  31.9275   -4.4285     22.03        21
# 155      155  san miguel el alto  21.0167 -102.3500     24.19        36
# 176      176       pacific grove  36.6177 -121.9166     21.61        58
# 198      198          las palmas  28.4204  -14.0131     23.44        47
# 226      226              tinajo  29.0788  -13.7081     22.49        83
# 239      239                ghat  24.9647   10.1728     21.31        33
# 279      279              mhamid  29.8200   -5.7200     24.46        19
# 317      317         al kharijah  25.4514   30.5464     21.41        38
# 347      347           jaisalmer  26.9147   70.9181     21.90        28
# 352      352              center  31.5107  -96.4247     23.22        54
# 393      393        mersa matruh  31.3525   27.2453     22.11        60
# 435      435             emerald -23.5333  148.1667     21.30        58
# 463      463            chabahar  25.2919   60.6430     25.41        53
# 473      473       sunrise manor  36.2111 -115.0731     22.91        23
# 562      562          cannonvale -20.2833  148.7000     22.66        85
#
#      Cloudiness  Wind Speed Country        Date
# 32            0        4.12      US  1699992045
# 33            0        3.65      PE  1699992045
# 67            0        3.09      US  1699991965
# 82            0        3.05      US  1699992007
# 129           0        0.00      MA  1699992074
# 155           0        2.76      MX  1699992081
# 176           0        2.57      US  1699992035
# 198           0        2.57      ES  1699992106
# 226           0        2.57      ES  1699992111
# 239           0        2.38      LY  1699992116
# 279           0        2.18      MA  1699992127
# 317           0        4.47      EG  1699992141
# 347           0        3.96      IN  1699991963
# 352           0        2.57      US  1699992152
# 393           0        4.12      EG  1699992170
# 435           0        2.13      AU  1699992195
# 463           0        1.41      IR  1699992205
# 473           0        2.68      US  1699992209
# 562           0        0.75      AU  1699992230

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity

hotel_df = narrowed_city_df[["City", "Country", "Lat","Lng","Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API

hotel_df["Hotel Name"] = ''
# Display sample data
hotel_df
# Out:
#                    City Country      Lat       Lng  Humidity Hotel Name
# 32         aransas pass      US  27.9095  -97.1500        76
# 33     minas de marcona      PE -15.2119  -75.1103        46
# 67            las vegas      US  36.1750 -115.1372        25
# 82               newman      US  37.3138 -121.0208        27
# 129          errachidia      MA  31.9275   -4.4285        21
# 155  san miguel el alto      MX  21.0167 -102.3500        36
# 176       pacific grove      US  36.6177 -121.9166        58
# 198          las palmas      ES  28.4204  -14.0131        47
# 226              tinajo      ES  29.0788  -13.7081        83
# 239                ghat      LY  24.9647   10.1728        33
# 279              mhamid      MA  29.8200   -5.7200        19
# 317         al kharijah      EG  25.4514   30.5464        38
# 347           jaisalmer      IN  26.9147   70.9181        28
# 352              center      US  31.5107  -96.4247        54
# 393        mersa matruh      EG  31.3525   27.2453        60
# 435             emerald      AU -23.5333  148.1667        58
# 463            chabahar      IR  25.2919   60.6430        53
# 473       sunrise manor      US  36.2111 -115.0731        23
# 562          cannonvale      AU -20.2833  148.7000        85

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories": "accommodation.hotel",
    'apiKey': geoapify_key,
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row['Lat']
    lng = row['Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lng},{lat},{radius}"
    params["bias"] = f"proximity:{lng},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params = params)
    
    # Convert the API response to JSON format 
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# aransas pass - nearest hotel: Executive Inn & Suites
# minas de marcona - nearest hotel: No hotel found
# las vegas - nearest hotel: Downtown Grand
# newman - nearest hotel: No hotel found
# errachidia - nearest hotel: No hotel found
# san miguel el alto - nearest hotel: No hotel found
# pacific grove - nearest hotel: Pacific Grove Inn
# las palmas - nearest hotel: Era de La Corte
# tinajo - nearest hotel: Villas Tinajo
# ghat - nearest hotel: فندق تاسيلي
# mhamid - nearest hotel: Hotel Kasbah Azalay
# al kharijah - nearest hotel: Kharga Hotel
# jaisalmer - nearest hotel: Jeet Mahal
# center - nearest hotel: No hotel found
# mersa matruh - nearest hotel: صقور
# emerald - nearest hotel: Emerald Central Hotel
# chabahar - nearest hotel: هتل سپیده
# sunrise manor - nearest hotel: Holiday Inn Express Las Vegas - Nellis
# cannonvale - nearest hotel: Whitsundays Rainforest Retreat
#                    City Country      Lat       Lng  Humidity  \
# 32         aransas pass      US  27.9095  -97.1500        76
# 33     minas de marcona      PE -15.2119  -75.1103        46
# 67            las vegas      US  36.1750 -115.1372        25
# 82               newman      US  37.3138 -121.0208        27
# 129          errachidia      MA  31.9275   -4.4285        21
# 155  san miguel el alto      MX  21.0167 -102.3500        36
# 176       pacific grove      US  36.6177 -121.9166        58
# 198          las palmas      ES  28.4204  -14.0131        47
# 226              tinajo      ES  29.0788  -13.7081        83
# 239                ghat      LY  24.9647   10.1728        33
# 279              mhamid      MA  29.8200   -5.7200        19
# 317         al kharijah      EG  25.4514   30.5464        38
# 347           jaisalmer      IN  26.9147   70.9181        28
# 352              center      US  31.5107  -96.4247        54
# 393        mersa matruh      EG  31.3525   27.2453        60
# 435             emerald      AU -23.5333  148.1667        58
# 463            chabahar      IR  25.2919   60.6430        53
# 473       sunrise manor      US  36.2111 -115.0731        23
# 562          cannonvale      AU -20.2833  148.7000        85
#
#                                  Hotel Name
# 32                   Executive Inn & Suites
# 33                           No hotel found
# 67                           Downtown Grand
# 82                           No hotel found
# 129                          No hotel found
# 155                          No hotel found
# 176                       Pacific Grove Inn
# 198                         Era de La Corte
# 226                           Villas Tinajo
# 239                             فندق تاسيلي
# 279                     Hotel Kasbah Azalay
# 317                            Kharga Hotel
# 347                              Jeet Mahal
# 352                          No hotel found
# 393                                    صقور
# 435                   Emerald Central Hotel
# 463                               هتل سپیده
# 473  Holiday Inn Express Las Vegas - Nellis
# 562          Whitsundays Rainforest Retreat

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = hotel_df.hvplot.points('Lng','Lat',
                                  geo=True,
                                  size = "Humidity",
                                  scale= 1,
                                  color = "City",
                                  alpha= 0.5,
                                  tiles = True,
                                  hover_cols = ['Hotel Name', "Country"]
                                 )
    
# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
